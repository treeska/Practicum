# %% [markdown]
# <h1>Анализ бизнес-показателей<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузска-данных-и-предобработка" data-toc-modified-id="Загрузска-данных-и-предобработка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузска данных и предобработка</a></span></li><li><span><a href="#Расчёт-и-анализ-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Расчёт-и-анализ-LTV,-ROI,-удержания-и-конверсии.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Расчёт и анализ LTV, ROI, удержания и конверсии.</a></span><ul class="toc-item"><li><span><a href="#Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функции для расчёта и анализа LTV, ROI, удержания и конверсии.</a></span><ul class="toc-item"><li><span><a href="#get_profiles()-—-для-создания-профилей-пользователей." data-toc-modified-id="get_profiles()-—-для-создания-профилей-пользователей.-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>get_profiles() — для создания профилей пользователей.</a></span></li><li><span><a href="#get_retention()-—-для-подсчёта-Retention-Rate." data-toc-modified-id="get_retention()-—-для-подсчёта-Retention-Rate.-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>get_retention() — для подсчёта Retention Rate.</a></span></li><li><span><a href="#get_conversion()-—-для-подсчёта-конверсии." data-toc-modified-id="get_conversion()-—-для-подсчёта-конверсии.-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>get_conversion() — для подсчёта конверсии.</a></span></li><li><span><a href="#get_ltv()-—-для-подсчёта-LTV." data-toc-modified-id="get_ltv()-—-для-подсчёта-LTV.-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>get_ltv() — для подсчёта LTV.</a></span></li><li><span><a href="#filter_data()-—-для-сглаживания-данных." data-toc-modified-id="filter_data()-—-для-сглаживания-данных.-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>filter_data() — для сглаживания данных.</a></span></li><li><span><a href="#plot_retention()-—-для-построения-графика-Retention-Rate." data-toc-modified-id="plot_retention()-—-для-построения-графика-Retention-Rate.-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>plot_retention() — для построения графика Retention Rate.</a></span></li><li><span><a href="#plot_conversion()-—-для-построения-графика-конверсии." data-toc-modified-id="plot_conversion()-—-для-построения-графика-конверсии.-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>plot_conversion() — для построения графика конверсии.</a></span></li><li><span><a href="#plot_ltv_roi-—-для-визуализации-LTV-и-ROI." data-toc-modified-id="plot_ltv_roi-—-для-визуализации-LTV-и-ROI.-2.1.8"><span class="toc-item-num">2.1.8&nbsp;&nbsp;</span>plot_ltv_roi — для визуализации LTV и ROI.</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Маркетинг</a></span></li><li><span><a href="#Окупаемость-рекламы" data-toc-modified-id="Окупаемость-рекламы-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Окупаемость-рекламы-на-графиках-LTV-и-ROI" data-toc-modified-id="Окупаемость-рекламы-на-графиках-LTV-и-ROI-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Окупаемость рекламы на графиках LTV и ROI</a></span></li><li><span><a href="#Конверсия-и-удержание-пользователей" data-toc-modified-id="Конверсия-и-удержание-пользователей-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Конверсия и удержание пользователей</a></span><ul class="toc-item"><li><span><a href="#Общие-графики-конверсии-и-удержания" data-toc-modified-id="Общие-графики-конверсии-и-удержания-2.4.2.1"><span class="toc-item-num">2.4.2.1&nbsp;&nbsp;</span>Общие графики конверсии и удержания</a></span></li><li><span><a href="#Конверсия-и-удержание-по-каналам" data-toc-modified-id="Конверсия-и-удержание-по-каналам-2.4.2.2"><span class="toc-item-num">2.4.2.2&nbsp;&nbsp;</span>Конверсия и удержание по каналам</a></span></li><li><span><a href="#Конверсия-и-удержание-по-странам" data-toc-modified-id="Конверсия-и-удержание-по-странам-2.4.2.3"><span class="toc-item-num">2.4.2.3&nbsp;&nbsp;</span>Конверсия и удержание по странам</a></span></li><li><span><a href="#Конверсия-и-удержание-по-устройствам" data-toc-modified-id="Конверсия-и-удержание-по-устройствам-2.4.2.4"><span class="toc-item-num">2.4.2.4&nbsp;&nbsp;</span>Конверсия и удержание по устройствам</a></span></li></ul></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам." data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам.-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по устройствам.</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по рекламным каналам</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></div>

# %% [markdown]
# Данное исследование сделано для развлекательного приложения Procrastinate Pro+.
# Предоставленные данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.
# В нашем распоряжении три датасета. Файл visits_info_short.csv хранит лог сервера с информацией о посещениях сайта, orders_info_short.csv — информацию о заказах, а costs_info_short.csv — информацию о расходах на рекламу.

# %% [markdown]
# **Цель исследования: Выяснить почему компания терпит убытки, несмотря на вложения в рекламу.**

# %% [markdown]
# ## Загрузска данных и предобработка

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# %%
visits = pd.read_csv('/datasets/visits_info_short.csv')
orders = pd.read_csv('/datasets/orders_info_short.csv')
costs = pd.read_csv('/datasets/costs_info_short.csv')

# %%
visits.info()
orders.info()
costs.info()
display(visits.sample(5, random_state=1))
display(orders.sample(5, random_state=1))
costs.sample(5, random_state=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %% [markdown]
# В нашем распоряжении три  датафрейма. Таблица visits хранит лог сервера с информацией о посещениях сайта, в ней содержится 309901 строк и 6 колонок. Таблица orders содержит данные о заказах, в ней 40212 строк и 3 колонки. Таблица costs показывает информацию о расходах на рекламу, в ней 1800 строк и 3 колонки. В каждом датафрейме необходимо изменить тип данных в колонках с датами.

# %%
display(visits.isna().sum()) 
display(orders.isna().sum()) 
display(costs.isna().sum()) 
display(visits.duplicated().sum())
display(orders.duplicated().sum())
costs.duplicated().sum()
# Out:
# User Id          0
# Region           0
# Device           0
# Channel          0
# Session Start    0
# Session End      0
# dtype: int64
# User Id     0
# Event Dt    0
# Revenue     0
# dtype: int64
# dt         0
# Channel    0
# costs      0
# dtype: int64
# 0
# 0
# 0

# %% [markdown]
# В данных нет пропосков и дубликатов.

# %% [markdown]
# Переименуем столбцы для удобства дальнейшего исследования

# %%
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns]
orders.columns = [x.lower().replace(' ', '_') for x in orders.columns]
costs.columns = costs.columns.str.lower()

# %% [markdown]
# Изменим тип данных в колонках с датами.

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %%
visits.info()
orders.info()
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# ...

# %% [markdown]
# **Загрузска данных и предобработка проведены. Продолжим исследование.**

# %% [markdown]
# ## Расчёт и анализ LTV, ROI, удержания и конверсии.

# %% [markdown]
# ### Функции для расчёта и анализа LTV, ROI, удержания и конверсии.

# %% [markdown]
# #### get_profiles() — для создания профилей пользователей.

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].values.astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())


    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# #### get_retention() — для подсчёта Retention Rate.

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### get_conversion() — для подсчёта конверсии.

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### get_ltv() — для подсчёта LTV.

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# #### filter_data() — для сглаживания данных.

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# #### plot_retention() — для построения графика Retention Rate.

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### plot_conversion() — для построения графика конверсии.

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### plot_ltv_roi — для визуализации LTV и ROI.

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 20))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(3, 2, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(3, 2, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(3, 2, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(3, 2, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(3, 2, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Были заданы все необходимые для исследования функции. Начнем анализ данных.**

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# Составим профили пользователей. Для этого вызовем функцию get_profiles(), передав ей данные о посещениях, покупках, событиях и затратах на рекламу.

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
print(profiles['dt'].min())
print(profiles['dt'].max())
# Out:
# 2019-05-01
# 2019-10-27

# %% [markdown]
# Минимальная дата привлечения пользователей 1 мая 2019, а максимальная - 27 октября 2019.

# %%
print(profiles['region'].unique())
# Out:
# ['United States' 'France' 'Germany' 'UK']

# %%
region_users = (
    profiles.groupby('region')['user_id'].nunique().reset_index()
    .merge(profiles[profiles['payer']==True].groupby('region')['user_id'].nunique().reset_index(), 
           on = 'region', how = 'left')
)
region_users.columns = ['region', 'total_users', 'payers']
region_users['payer_rate'] = region_users['payers'] / region_users['total_users']
display(region_users.sort_values(by='payer_rate', ascending=False))
# Out:
#           region  total_users  payers  payer_rate
# 3  United States       100002    6902    0.069019
# 1        Germany        14981     616    0.041119
# 2             UK        17575     700    0.039829
# 0         France        17450     663    0.037994

# %%
colors= ["teal", "orange", "skyblue", "purple"]
regions = region_users['region'].unique()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (17, 7))
region_users['total_users'].plot(kind='pie', pctdistance=0.5, labeldistance=1.2, colors=colors, labels=regions, autopct='%1.1f%%', ax=ax1)
region_users['payers'].plot(kind='pie', pctdistance=0.5, labeldistance=1.2, colors=colors, labels=regions, autopct='%1.1f%%', ax=ax2)
plt.show()

# %% [markdown]
# Больше всего пользователей приложения из США. В этой же стране самая большая доля платящих пользователей, почти 70%. В то время как в других странах доля платящих пользователей не превышает 42%.

# %%
print(profiles['device'].unique())
# Out:
# ['Mac' 'iPhone' 'PC' 'Android']

# %%
device_users = (
    profiles.groupby('device')['user_id'].nunique().reset_index()
    .merge(profiles[profiles['payer']==True].groupby('device')['user_id'].nunique().reset_index(), on = 'device', how = 'left')
)
device_users.columns = ['device', 'total_users', 'payers']
device_users['payer_rate'] = device_users['payers'] / device_users['total_users']
device_users.sort_values(by='payer_rate', ascending=False)
# Out:
#     device  total_users  payers  payer_rate
# 1      Mac        30042    1912    0.063644
# 3   iPhone        54479    3382    0.062079
# 0  Android        35032    2050    0.058518
# 2       PC        30455    1537    0.050468

# %%
devices = device_users['device'].unique()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (17, 7))
device_users['total_users'].plot(kind='pie', pctdistance=0.5, labeldistance=1.2, colors=colors, labels=devices, autopct='%1.1f%%', ax=ax1)
device_users['payers'].plot(kind='pie', pctdistance=0.5, labeldistance=1.2, colors=colors, labels=devices, autopct='%1.1f%%', ax=ax2)
plt.show()

# %% [markdown]
# Распределение пользователей по устройствам выглядит более равномерно. Больше всего пользователей заходит в приложение через iPhone, меньше всего - через PC и Mac. Доля платящих пользователей выше у iPhone.

# %%
reg_dev = profiles.pivot_table(index='device', columns='region', values='user_id', aggfunc='nunique').reset_index()
reg_dev
# Out:
# region   device  France  Germany    UK  United States
# 0       Android    5252     4440  5141          20199
# 1           Mac    1838     1584  1778          24842
# 2            PC    6940     5945  7138          10432
# 3        iPhone    3420     3012  3518          44529

# %%
devices1 = reg_dev['device'].unique()
fig, (axes) = plt.subplots(2, 2, figsize = (14, 9))
reg_dev['France'].plot(kind='pie', pctdistance=0.5, labeldistance=1.2, colors=colors, labels=devices1, autopct='%1.1f%%', ax=axes[0,0])
reg_dev['Germany'].plot(kind='pie', pctdistance=0.5, labeldistance=1.2, colors=colors, labels=devices1, autopct='%1.1f%%', ax=axes[0,1])
reg_dev['UK'].plot(kind='pie', pctdistance=0.5, labeldistance=1.2, colors=colors, labels=devices1, autopct='%1.1f%%', ax=axes[1,0])
reg_dev['United States'].plot(kind='pie', pctdistance=0.5, labeldistance=1.1, colors=colors, labels=devices1, autopct='%1.1f%%', ax=axes[1,1])
plt.show()

# %% [markdown]
# Распределение девайсов пользователей в США существенно отличается от стран Европы. В США чаще используют iPhone и Mac, в то время как в Европе наиболее популярны PC и Android.

# %%
print(profiles.channel.unique())
# Out:
# ['FaceBoom' 'organic' 'AdNonSense' 'YRabbit' 'MediaTornado'
#  'RocketSuperAds' 'LeapBob' 'TipTop' 'WahooNetBanner' 'OppleCreativeMedia'
#  'lambdaMediaAds']

# %%
channel_users = (
    profiles.groupby('channel')['user_id'].nunique().reset_index()
    .merge(profiles[profiles['payer']==True].groupby('channel')['user_id'].nunique().reset_index(), on = 'channel', how = 'left')
)
channel_users.columns = ['channel', 'total_users', 'payers']
channel_users['payer_rate'] = channel_users.payers / channel_users.total_users
channel_users.sort_values(by='payer_rate', ascending=False)
# Out:
#                channel  total_users  payers  payer_rate
# 1             FaceBoom        29144    3557    0.122049
# 0           AdNonSense         3880     440    0.113402
# 9       lambdaMediaAds         2149     225    0.104700
# 6               TipTop        19561    1878    0.096007
# 5       RocketSuperAds         4448     352    0.079137
# 7       WahooNetBanner         8553     453    0.052964
# 8              YRabbit         4312     165    0.038265
# 3         MediaTornado         4364     156    0.035747
# 2              LeapBob         8553     262    0.030633
# 4   OppleCreativeMedia         8605     233    0.027077
# 10             organic        56439    1160    0.020553

# %%
print(channel_users['payers'].sum() / channel_users['total_users'].sum() * 100)
# Out:
# 5.920350914617887

# %% [markdown]
# 94 % пользователей приложения являются неплатящими.

# %%
channel_users.set_index('channel', inplace=True)
channel_users.plot(kind="bar", color = colors, figsize=(10, 6))
plt.xticks(rotation=70)
plt.title('Рекламные источники привлечения')
plt.xlabel('Источники')
plt.ylabel('Пользователи')
plt.show()

# %% [markdown]
# Доля платящих пользователей у всех каналов привлечения крайне мала. Наиболее успешными можно назвать FaceBoom и TipTop. Они привлекли много пользователей в приложение, и десятая часть из них конвертировалась в платящих.

# %%
reg_ch = profiles.pivot_table(index='channel', columns = 'region', values = 'user_id', aggfunc='count')
reg_ch.sort_values('United States')
# Out:
# region              France  Germany      UK  United States
# channel
# YRabbit                NaN      NaN     NaN         4312.0
# MediaTornado           NaN      NaN     NaN         4364.0
# RocketSuperAds         NaN      NaN     NaN         4448.0
# TipTop                 NaN      NaN     NaN        19561.0
# FaceBoom               NaN      NaN     NaN        29144.0
# organic             6392.0   5453.0  6421.0        38173.0
# AdNonSense          1366.0   1219.0  1295.0            NaN
# LeapBob             2988.0   2519.0  3046.0            NaN
# OppleCreativeMedia  2991.0   2562.0  3052.0            NaN
# WahooNetBanner      2971.0   2579.0  3003.0            NaN
# lambdaMediaAds       742.0    649.0   758.0            NaN

# %% [markdown]
# У стран Европы и США разные каналы привлечения пользователей. Эта информация может быть полезна при дальнешем изучении

# %% [markdown]
# **Резюмируем:**
#
# **- Больше всего пользователей приложения из США. В этой же стране самая большая доля платящих пользователей, почти 70%. В то время как в других странах доля платящих пользователей не превышает 42%.**
#
# **- Больше всего пользователей заходит в приложение через iPhone, меньше всего - через PC и Mac. Доля платящих пользователей выше у iPhone.**
#
# **- В США чаще используют iPhone и Mac, в то время как в Европе наиболее популярны PC и Android.**
#
# **- Доля платящих пользователей у всех каналов привлечения крайне мала. Наиболее успешными можно назвать американские FaceBoom и TipTop.**
#
# **- 94 % пользователей приложения являются неплатящими.**
#
# **- У стран Европы и США разные каналы привлечения пользователей.**

# %% [markdown]
# ### Маркетинг

# %%
costs['costs'].sum().round(2)
# Out:
# 105497.3

# %% [markdown]
# Такова общая сумма расходов на маркетинг.

# %%
costs_channel = costs.groupby('channel')['costs'].sum()
costs_channel.sort_values(ascending=False).plot(kind="bar", color = 'teal', figsize=(10, 6))
plt.xticks(rotation=70)
plt.title('Расходы на рекламные источники привлечения')
plt.xlabel('Источники')
plt.ylabel('Расходы')
plt.show()

# %% [markdown]
# TipTop -самый дорогостоящий источник рекламы, FaceBoom - на втором месте, остальные источники идут с сильным отрывом и не несут столько расходов.

# %%
costs['dt'] = pd.to_datetime(costs['dt'])
costs['week'] = costs['dt'].dt.isocalendar().week
costs['month'] = costs['dt'].dt.month

# %%
list_ch = costs['channel'].unique()
dinamic_costs = costs.pivot_table(index=['channel','week'], values = ['costs'], aggfunc = 'sum')
dinamic_costs = dinamic_costs.reset_index('week')
fig, ax = plt.subplots(figsize =(10,7))
for channel in list_ch:
    dinamic_costs.loc[channel].plot('week', 'costs', ax=ax)
ax.legend(list_ch, bbox_to_anchor=(1.02, 1))
plt.title('Динамики изменения расходов по неделям по каждому источнику')
plt.xlabel('Недели')
plt.ylabel('Расходы')
plt.show()

# %%
dinamic_costs2 = costs.pivot_table(index=['channel','month'], values = ['costs'], aggfunc = 'sum')
dinamic_costs2 = dinamic_costs2.reset_index('month')
fig, ax = plt.subplots(figsize =(10,7))
for channel in list_ch:
    dinamic_costs2.loc[channel].plot('month', 'costs', ax=ax)
ax.legend(list_ch, bbox_to_anchor=(1.02, 1))
plt.title('Динамики изменения расходов по месяцам по каждому источнику')
plt.xlabel('Месяц')
plt.ylabel('Расходы')
plt.show()

# %% [markdown]
# Расходы на TipTop и FaceBoom постоянно растут, в отличие от других источников привлечения пользователей.

# %%
mean_cac = profiles.pivot_table(index='channel', values='acquisition_cost', aggfunc='mean')
display(mean_cac['acquisition_cost'].sort_values(ascending=False))
mean_cac['acquisition_cost'].sort_values(ascending=False).plot(kind="bar", color = 'teal', figsize=(10, 6))
plt.xticks(rotation=70)
plt.title('Средняя стоимость привлечения одного пользователя по источникам')
plt.xlabel('Стоимость')
plt.ylabel('Источник')
plt.show()
# Out:
# channel
# TipTop                2.799003
# FaceBoom              1.113286
# AdNonSense            1.008054
# lambdaMediaAds        0.724802
# WahooNetBanner        0.602245
# RocketSuperAds        0.412095
# OppleCreativeMedia    0.250000
# YRabbit               0.218975
# MediaTornado          0.218717
# LeapBob               0.210172
# organic               0.000000
# Name: acquisition_cost, dtype: float64

# %% [markdown]
# TipTop самый дорогой источник привлечения пользователей, однако мы помним, что и самый эффективный.

# %% [markdown]
# **Промежуточные выводы:**
#
# **- Общая сумма расходов на маркетинг - 105497**
#
# **- TipTop - самый дорогостоящий источник рекламы, FaceBoom - на втором месте, остальные источники идут с сильным отрывом и не несут столько расходов. Но и пользователей привлекают крайне мало.**
#
# **- TipTop самый дорогой источник привлечения пользователей, но и самый эффективный по доле платящих пользователей.**

# %% [markdown]
# ### Окупаемость рекламы

# %% [markdown]
# Зададим дату наблюдения - 1 ноября 2010 и горизонт анализа в 14 дней.Так как в нашей компании принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %%
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# %% [markdown]
# Цель нашего исследования оценить окупаемость рекламы, поэтому мы исключим органических пользователей.

# %%
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# #### Окупаемость рекламы на графиках LTV и ROI

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Предворительные выводы:
#
# - Реклама не окупается. ROI на 14 день — чуть выше 80%.
# - В динамике ROI изначально окупался, но с июня упал за черту уровня окупаемости и продолжает падать.
# - В это же время стоимость привлечения пользователей постоянно растет
# - Показатель LTV достаточно стабилен. Значит, дело не в ухудшении качества пользователей.

# %% [markdown]
# #### Конверсия и удержание пользователей

# %% [markdown]
# ##### Общие графики конверсии и удержания

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Судя по графикам, пользователи конвертируются очень хорошо, причём постоянно. Видимо, дело в удержании. Построим график удержания

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# По графику динамики удержания неплатящих пользователей, можно сказать, что неплатящие пользователи не удерживаются в приложении.

# %% [markdown]
# ##### Конверсия и удержание по каналам

# %%
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Пользователи конвертируются очень хорошо и постоянно. Лучше всего конверсия происходит через каналы FaceBoom, AdNonSense и ambdaMediaAds.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# В тоже время удержание платящих пользователей хуже всего у FaceBoom и AdNonSense.

# %% [markdown]
# ##### Конверсия и удержание по странам

# %%
dimensions = ['region']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Пользователи намного США лучше конвертируются, чем европейские

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Показатель удержания платящих пользователей у США хуже всего

# %% [markdown]
# ##### Конверсия и удержание по устройствам

# %%
dimensions = ['device']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Хуже всего конвертируются пользователи PC

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Промежуточные выводы**
# - Основная проблема неокупаемости рекламы заметнее всего в США, хоть здесь и лучше конверсия, но потом платящие пользователи не удерживаются
# - С неплатящими пользователями ситуация везде одинаковая, они не удерживаются

# %% [markdown]
# #### Окупаемость рекламы с разбивкой по устройствам.

# %%
dimensions = ['device']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - LTV всех устройств стабилен
# - Стоимость привлечения пользователей iPhone и Mac выше, чем Android и PC
# - Окупается только PC, едва выходя за уровень окупаемости
# - Окупаемость пользователей всех устройств имеет тенденцию к падению проходя под уровнем окупаемости.

# %% [markdown]
# #### Окупаемость рекламы с разбивкой по странам

# %%
dimensions = ['region']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - LTV пользователей США выше европейских. Однако и стоимость их привлечения намного выше, а инвестиции в привлечение этих пользователей проходят не окупаются.
# - В странах Европы с января отсутсвует динамика в стоимости привлечения пользователей.
# - Инвестиции в рекламу обходятся чересчур дорого, так как стоимость привлечения растет, но не оказывает положительного воздействия в конверсию пользователей.

# %% [markdown]
# #### Окупаемость рекламы с разбивкой по рекламным каналам

# %%
profiles_usa = profiles.query('region == "United States"')

dimensions = ['channel']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_usa, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# На этих графиках только американские рекламные каналы, для удобства визуализации.
# - Самые успешные по привлечению пользователей источники TipTop и FaceBoom находятся ниже уровня окупаемости, в отличие от остальных.
# - В это же время стоимость привлечения пользователей через TipTop стремительно увеличиваются.
# - Графики по стоимости привлечения по США и по каналу TipTop очень похожи. Возможно основная проблема неокупаемости рекламы находится здесь.

# %%
profiles_eu = profiles.query('region == "France"')
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_eu, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - Среди европейских каналов привлечения пользователей наиболее выгодный и успешный lambdaMediaAds. В то же время прерывистость графиков говорит о не стабильной работе этого канала
# - AdNonSense не окупается

# %% [markdown]
# **Промежуточные выводы**
#
# **- Неплатящие пользователи не удерживаются в приложении.**
#
# **- Инвестиции в рекламу совершенно не окупаются**
#
# **- Плохая окупаемость характерна для всех устройств**
#
# **- Проблема окупаемости в особенности касается пользователей США. Именно здесь высокие расходы на рекламу совершенно не окупаются.**
#
# **- Причина неокупаемости рекламы может быть в чрезмерных расходах на американские источники привлечения пользвателей TipTop и FaceBoom. В особенности TipTop, расходы на него постоянно растут, но это не оказывает положительного эффекта. А также сильно влияет на стоимость привлечения пользователя по этому региону.**
#
# **По этой причине рекламному отделу необходимо задуматься об изменениях условий сотрудничества с рекламными каналами TipTop и FaceBoom.**

# %% [markdown]
# ### Выводы

# %% [markdown]
# **В ходе исследования были обнаружены проблемы с окупаемостью привлечения пользователей приложения Procrastinate Pro+. Были изучены предоставленные данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года. В ходе исследования были составлены профили пользователей для дальнейшего построения графиков важнейших показателей окупаемости затрат. Были сделаны следующие выводы:**
#
# **- Больше всего пользователей приложения из США. В этой же стране самая большая доля платящих пользователей, почти 70%. В то время как в других странах доля платящих пользователей не превышает 42%.**
#
# **- Инвестиции в рекламу совершенно не окупаются.**
#
# **- Плохая окупаемость характерна для всех устройств.**
#
# **- Проблема окупаемости в особенности касается пользователей США. Именно здесь высокие расходы на рекламу совершенно не окупаются.**
#
# **- Причина неокупаемости рекламы может быть в чрезмерных расходах на американские источники привлечения пользвателей TipTop и FaceBoom. В особенности TipTop, расходы на него постоянно растут, но это не оказывает положительного эффекта. А также сильно влияет на стоимость привлечения пользователя по этому региону.**
#
# **- В Европе не окупается источник привлечения пользователей AdNonSense.**
#
# **Рекомендации для отдела маркетинга:**
#
# **- Необходимо обратить внимание на удержание неплатящих пользователей. Эта категория не задерживается в приложении. В тоже время это более 90% пользователей приложения. Может быть предоставить некий пробный период пользования приложением, чтобы стимулировать конверсию.**
#
# **- По причине высоких расходов на рекламные источники привлечения пользователей TipTop и FaceBoom и их низкую эффективность по сравнению с другими источниками необходимо пересмотреть условия сотрудничества с ними. А также пересмотреть расходы на рекламу в США в пользу других каналов.**
#
# **- Стоит обратить внимание на европейски канал привлечения пользователей AdNonSense, так как расходы на него также не окупаются.**
#
# **- Среди европейских каналов привлечения пользователей наиболее выгодный и успешный lambdaMediaAds. Может быть стоит пересмотреть расходы на рекламу в Европе в его пользу.**
